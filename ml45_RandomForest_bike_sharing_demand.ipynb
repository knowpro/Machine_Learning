# %%
import pandas as pd
import numpy as np

from sklearn.ensemble import RandomForestRegressor

from sklearn.metrics import accuracy_score, roc_auc_score
from sklearn.metrics import r2_score

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import GridSearchCV

# %%
bk_train = pd.read_csv(r"Cases\Bike Sharing Demand\train.csv",
                      index_col = 0)

# %%
bk_train.head()
# Out:
#                season  holiday  workingday  weather  temp   atemp  humidity  \
# datetime
# 1/1/2011 0:00       1        0           0        1  9.84  14.395        81
# 1/1/2011 1:00       1        0           0        1  9.02  13.635        80
# 1/1/2011 2:00       1        0           0        1  9.02  13.635        80
# 1/1/2011 3:00       1        0           0        1  9.84  14.395        75
# 1/1/2011 4:00       1        0           0        1  9.84  14.395        75
#
#                windspeed  casual  registered  count
# datetime
# 1/1/2011 0:00        0.0       3          13     16
# 1/1/2011 1:00        0.0       8          32     40
# 1/1/2011 2:00        0.0       5          27     32
# 1/1/2011 3:00        0.0       3          10     13
# 1/1/2011 4:00        0.0       0           1      1

# %%
X_train = bk_train.drop(["count", "casual", "registered"], axis = 1)
y_train = bk_train["count"]

# %%
bk_test = pd.read_csv(r"Cases\Bike Sharing Demand\test.csv",
                     index_col = 0)

# %%
bk_test.head()
# Out:
#                      season  holiday  workingday  weather   temp   atemp  \
# datetime
# 2011-01-20 00:00:00       1        0           1        1  10.66  11.365
# 2011-01-20 01:00:00       1        0           1        1  10.66  13.635
# 2011-01-20 02:00:00       1        0           1        1  10.66  13.635
# 2011-01-20 03:00:00       1        0           1        1  10.66  12.880
# 2011-01-20 04:00:00       1        0           1        1  10.66  12.880
#
#                      humidity  windspeed
# datetime
# 2011-01-20 00:00:00        56    26.0027
# 2011-01-20 01:00:00        56     0.0000
# 2011-01-20 02:00:00        56     0.0000
# 2011-01-20 03:00:00        56    11.0014
# 2011-01-20 04:00:00        56    11.0014

# %%
X_test = bk_test

# %%
rf = RandomForestRegressor(random_state = 2022)

rf.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=2022)
