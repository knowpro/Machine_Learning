# %%
import pandas as pd
import numpy as np

from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score

from sklearn.model_selection import train_test_split
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

from sklearn.svm import SVC

from sklearn.pipeline import Pipeline

from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder

import os

# %%
os.chdir(r"C:\Hogwarts\machine_learning\Cases\Image Segmentation")
img = pd.read_csv("Image_Segmentation.csv")
img.head()
# Out:
#        Class  region.centroid.col  region.centroid.row  region.pixel.count  \
# 0  BRICKFACE                  188                  133                   9
# 1  BRICKFACE                  105                  139                   9
# 2  BRICKFACE                   34                  137                   9
# 3  BRICKFACE                   39                  111                   9
# 4  BRICKFACE                   16                  128                   9
#
#    short.line.density.5  short.line.density.2  vedge.mean  vegde.sd  \
# 0                   0.0                   0.0    0.333333  0.266667
# 1                   0.0                   0.0    0.277778  0.107407
# 2                   0.0                   0.0    0.500000  0.166667
# 3                   0.0                   0.0    0.722222  0.374074
# 4                   0.0                   0.0    0.500000  0.077778
#
#    hedge.mean  hedge.sd  intensity.mean  rawred.mean  rawblue.mean  \
# 0    0.500000  0.077778        6.666666     8.333334      7.777778
# 1    0.833333  0.522222        6.111111     7.555555      7.222222
# 2    1.111111  0.474074        5.851852     7.777778      6.444445
# 3    0.888889  0.429629        6.037037     7.000000      7.666666
# 4    0.666667  0.311111        5.555555     6.888889      6.666666
#
#    rawgreen.mean  exred.mean  exblue.mean  exgreen.mean  value.mean  \
# 0       3.888889    5.000000     3.333333     -8.333333    8.444445
# 1       3.555556    4.333334     3.333333     -7.666666    7.555555
# 2       3.333333    5.777778     1.777778     -7.555555    7.777778
# 3       3.444444    2.888889     4.888889     -7.777778    7.888889
# 4       3.111111    4.000000     3.333333     -7.333334    7.111111
#
#    saturation.mean  hue-mean
# 0         0.538580 -0.924817
# 1         0.532628 -0.965946
# 2         0.573633 -0.744272
# 3         0.562919 -1.175773
# 4         0.561508 -0.985811

# %%
X = img.drop("Class", axis = 1)

y = img["Class"]

# %%
le = LabelEncoder()
le_y = le.fit_transform(y)

print(le.classes_)
# Out:
# ['BRICKFACE' 'CEMENT' 'FOLIAGE' 'GRASS' 'PATH' 'SKY' 'WINDOW']

# %%
scaler = StandardScaler()

# %%
svm = SVC(kernel = "linear",
         probability = True,
         random_state = 2022)

# %%
pipe = Pipeline([("STD", scaler), ("SVM", svm)])
print(pipe.get_params())
# Out:
# {'memory': None, 'steps': [('STD', StandardScaler()), ('SVM', SVC(kernel='linear', probability=True, random_state=2022))], 'verbose': False, 'STD': StandardScaler(), 'SVM': SVC(kernel='linear', probability=True, random_state=2022), 'STD__copy': True, 'STD__with_mean': True, 'STD__with_std': True, 'SVM__C': 1.0, 'SVM__break_ties': False, 'SVM__cache_size': 200, 'SVM__class_weight': None, 'SVM__coef0': 0.0, 'SVM__decision_function_shape': 'ovr', 'SVM__degree': 3, 'SVM__gamma': 'scale', 'SVM__kernel': 'linear', 'SVM__max_iter': -1, 'SVM__probability': True, 'SVM__random_state': 2022, 'SVM__shrinking': True, 'SVM__tol': 0.001, 'SVM__verbose': False}

# %%
params = {"SVM__C": np.linspace(0.001, 10, 20),
         "SVM__decision_function_shape": ["ovo", "ovr"] }

# %%
kfold = StratifiedKFold(n_splits = 5,
                        shuffle = True,
                        random_state = 2022)

# %%
gcv = GridSearchCV(pipe,
                  param_grid = params,
                  cv = kfold,
                  verbose = 3,
                  scoring = "neg_log_loss")
gcv.fit(X, y)
# Out:
# Fitting 5 folds for each of 40 candidates, totalling 200 fits
# [CV 1/5] END SVM__C=0.001, SVM__decision_function_shape=ovo;, score=-1.755 total time=   0.0s
# [CV 2/5] END SVM__C=0.001, SVM__decision_function_shape=ovo;, score=-1.752 total time=   0.0s
# [CV 3/5] END SVM__C=0.001, SVM__decision_function_shape=ovo;, score=-1.755 total time=   0.0s
# [CV 4/5] END SVM__C=0.001, SVM__decision_function_shape=ovo;, score=-1.756 total time=   0.0s
# [CV 5/5] END SVM__C=0.001, SVM__decision_function_shape=ovo;, score=-1.774 total time=   0.0s
# [CV 1/5] END SVM__C=0.001, SVM__decision_function_shape=ovr;, score=-1.755 total time=   0.0s
# [CV 2/5] END SVM__C=0.001, SVM__decision_function_shape=ovr;, score=-1.752 total time=   0.0s
# [CV 3/5] END SVM__C=0.001, SVM__decision_function_shape=ovr;, score=-1.755 total time=   0.0s
# [CV 4/5] END SVM__C=0.001, SVM__decision_function_shape=ovr;, score=-1.756 total time=   0.0s
# [CV 5/5] END SVM__C=0.001, SVM__decision_function_shape=ovr;, score=-1.774 total time=   0.0s
# [CV 1/5] END SVM__C=0.5272631578947369, SVM__decision_function_shape=ovo;, score=-0.402 total time=   0.0s
# [CV 2/5] END SVM__C=0.5272631578947369, SVM__decision_function_shape=ovo;, score=-0.464 total time=   0.0s
# [CV 3/5] END SVM__C=0.5272631578947369, SVM__decision_function_shape=ovo;, score=-0.405 total time=   0.0s
# [CV 4/5] END SVM__C=0.5272631578947369, SVM__decision_function_shape=ovo;, score=-0.425 total time=   0.0s
# [CV 5/5] END SVM__C=0.5272631578947369, SVM__decision_function_shape=ovo;, score=-0.424 total time=   0.0s
# [CV 1/5] END SVM__C=0.5272631578947369, SVM__decision_function_shape=ovr;, score=-0.402 total time=   0.0s
# [CV 2/5] END SVM__C=0.5272631578947369, SVM__decision_function_shape=ovr;, score=-0.464 total time=   0.0s
# [CV 3/5] END SVM__C=0.5272631578947369, SVM__decision_function_shape=ovr;, score=-0.405 total time=   0.0s
# [CV 4/5] END SVM__C=0.5272631578947369, SVM__decision_function_shape=ovr;, score=-0.425 total time=   0.0s
# [CV 5/5] END SVM__C=0.5272631578947369, SVM__decision_function_shape=ovr;, score=-0.424 total time=   0.0s
# [CV 1/5] END SVM__C=1.0535263157894736, SVM__decision_function_shape=ovo;, score=-0.390 total time=   0.0s
# [CV 2/5] END SVM__C=1.0535263157894736, SVM__decision_function_shape=ovo;, score=-0.441 total time=   0.0s
# [CV 3/5] END SVM__C=1.0535263157894736, SVM__decision_function_shape=ovo;, score=-0.370 total time=   0.0s
# [CV 4/5] END SVM__C=1.0535263157894736, SVM__decision_function_shape=ovo;, score=-0.413 total time=   0.0s
# [CV 5/5] END SVM__C=1.0535263157894736, SVM__decision_function_shape=ovo;, score=-0.408 total time=   0.0s
# [CV 1/5] END SVM__C=1.0535263157894736, SVM__decision_function_shape=ovr;, score=-0.390 total time=   0.0s
# [CV 2/5] END SVM__C=1.0535263157894736, SVM__decision_function_shape=ovr;, score=-0.441 total time=   0.0s
# [CV 3/5] END SVM__C=1.0535263157894736, SVM__decision_function_shape=ovr;, score=-0.370 total time=   0.0s
# [CV 4/5] END SVM__C=1.0535263157894736, SVM__decision_function_shape=ovr;, score=-0.413 total time=   0.0s
# [CV 5/5] END SVM__C=1.0535263157894736, SVM__decision_function_shape=ovr;, score=-0.408 total time=   0.0s
# [CV 1/5] END SVM__C=1.5797894736842104, SVM__decision_function_shape=ovo;, score=-0.390 total time=   0.0s
# [CV 2/5] END SVM__C=1.5797894736842104, SVM__decision_function_shape=ovo;, score=-0.448 total time=   0.0s
# [CV 3/5] END SVM__C=1.5797894736842104, SVM__decision_function_shape=ovo;, score=-0.358 total time=   0.0s
# [CV 4/5] END SVM__C=1.5797894736842104, SVM__decision_function_shape=ovo;, score=-0.427 total time=   0.0s
# [CV 5/5] END SVM__C=1.5797894736842104, SVM__decision_function_shape=ovo;, score=-0.415 total time=   0.0s
# [CV 1/5] END SVM__C=1.5797894736842104, SVM__decision_function_shape=ovr;, score=-0.390 total time=   0.0s
# [CV 2/5] END SVM__C=1.5797894736842104, SVM__decision_function_shape=ovr;, score=-0.448 total time=   0.0s
# [CV 3/5] END SVM__C=1.5797894736842104, SVM__decision_function_shape=ovr;, score=-0.358 total time=   0.0s
# [CV 4/5] END SVM__C=1.5797894736842104, SVM__decision_function_shape=ovr;, score=-0.427 total time=   0.0s
# [CV 5/5] END SVM__C=1.5797894736842104, SVM__decision_function_shape=ovr;, score=-0.415 total time=   0.0s
# [CV 1/5] END SVM__C=2.1060526315789474, SVM__decision_function_shape=ovo;, score=-0.393 total time=   0.0s
# [CV 2/5] END SVM__C=2.1060526315789474, SVM__decision_function_shape=ovo;, score=-0.458 total time=   0.0s
# [CV 3/5] END SVM__C=2.1060526315789474, SVM__decision_function_shape=ovo;, score=-0.355 total time=   0.0s
# [CV 4/5] END SVM__C=2.1060526315789474, SVM__decision_function_shape=ovo;, score=-0.438 total time=   0.0s
# [CV 5/5] END SVM__C=2.1060526315789474, SVM__decision_function_shape=ovo;, score=-0.422 total time=   0.0s
# [CV 1/5] END SVM__C=2.1060526315789474, SVM__decision_function_shape=ovr;, score=-0.393 total time=   0.0s
# [CV 2/5] END SVM__C=2.1060526315789474, SVM__decision_function_shape=ovr;, score=-0.458 total time=   0.0s
# [CV 3/5] END SVM__C=2.1060526315789474, SVM__decision_function_shape=ovr;, score=-0.355 total time=   0.0s
# [CV 4/5] END SVM__C=2.1060526315789474, SVM__decision_function_shape=ovr;, score=-0.438 total time=   0.0s
# [CV 5/5] END SVM__C=2.1060526315789474, SVM__decision_function_shape=ovr;, score=-0.422 total time=   0.0s
# [CV 1/5] END SVM__C=2.6323157894736844, SVM__decision_function_shape=ovo;, score=-0.396 total time=   0.0s
# [CV 2/5] END SVM__C=2.6323157894736844, SVM__decision_function_shape=ovo;, score=-0.464 total time=   0.0s
# [CV 3/5] END SVM__C=2.6323157894736844, SVM__decision_function_shape=ovo;, score=-0.364 total time=   0.0s
# [CV 4/5] END SVM__C=2.6323157894736844, SVM__decision_function_shape=ovo;, score=-0.439 total time=   0.0s
# [CV 5/5] END SVM__C=2.6323157894736844, SVM__decision_function_shape=ovo;, score=-0.424 total time=   0.0s
# [CV 1/5] END SVM__C=2.6323157894736844, SVM__decision_function_shape=ovr;, score=-0.396 total time=   0.0s
# [CV 2/5] END SVM__C=2.6323157894736844, SVM__decision_function_shape=ovr;, score=-0.464 total time=   0.0s
# [CV 3/5] END SVM__C=2.6323157894736844, SVM__decision_function_shape=ovr;, score=-0.364 total time=   0.0s
# [CV 4/5] END SVM__C=2.6323157894736844, SVM__decision_function_shape=ovr;, score=-0.439 total time=   0.0s
# [CV 5/5] END SVM__C=2.6323157894736844, SVM__decision_function_shape=ovr;, score=-0.424 total time=   0.0s
# [CV 1/5] END SVM__C=3.158578947368421, SVM__decision_function_shape=ovo;, score=-0.402 total time=   0.0s
# [CV 2/5] END SVM__C=3.158578947368421, SVM__decision_function_shape=ovo;, score=-0.467 total time=   0.0s
# [CV 3/5] END SVM__C=3.158578947368421, SVM__decision_function_shape=ovo;, score=-0.372 total time=   0.0s
# [CV 4/5] END SVM__C=3.158578947368421, SVM__decision_function_shape=ovo;, score=-0.443 total time=   0.0s
# [CV 5/5] END SVM__C=3.158578947368421, SVM__decision_function_shape=ovo;, score=-0.420 total time=   0.0s
# [CV 1/5] END SVM__C=3.158578947368421, SVM__decision_function_shape=ovr;, score=-0.402 total time=   0.0s
# [CV 2/5] END SVM__C=3.158578947368421, SVM__decision_function_shape=ovr;, score=-0.467 total time=   0.0s
# [CV 3/5] END SVM__C=3.158578947368421, SVM__decision_function_shape=ovr;, score=-0.372 total time=   0.0s
# [CV 4/5] END SVM__C=3.158578947368421, SVM__decision_function_shape=ovr;, score=-0.443 total time=   0.0s
# [CV 5/5] END SVM__C=3.158578947368421, SVM__decision_function_shape=ovr;, score=-0.420 total time=   0.0s
# [CV 1/5] END SVM__C=3.684842105263158, SVM__decision_function_shape=ovo;, score=-0.407 total time=   0.0s
# [CV 2/5] END SVM__C=3.684842105263158, SVM__decision_function_shape=ovo;, score=-0.476 total time=   0.0s
# [CV 3/5] END SVM__C=3.684842105263158, SVM__decision_function_shape=ovo;, score=-0.380 total time=   0.0s
# [CV 4/5] END SVM__C=3.684842105263158, SVM__decision_function_shape=ovo;, score=-0.444 total time=   0.0s
# [CV 5/5] END SVM__C=3.684842105263158, SVM__decision_function_shape=ovo;, score=-0.416 total time=   0.0s
# [CV 1/5] END SVM__C=3.684842105263158, SVM__decision_function_shape=ovr;, score=-0.407 total time=   0.0s
# [CV 2/5] END SVM__C=3.684842105263158, SVM__decision_function_shape=ovr;, score=-0.476 total time=   0.0s
# [CV 3/5] END SVM__C=3.684842105263158, SVM__decision_function_shape=ovr;, score=-0.380 total time=   0.0s
# [CV 4/5] END SVM__C=3.684842105263158, SVM__decision_function_shape=ovr;, score=-0.444 total time=   0.0s
# [CV 5/5] END SVM__C=3.684842105263158, SVM__decision_function_shape=ovr;, score=-0.416 total time=   0.0s
# [CV 1/5] END SVM__C=4.211105263157895, SVM__decision_function_shape=ovo;, score=-0.408 total time=   0.0s
# [CV 2/5] END SVM__C=4.211105263157895, SVM__decision_function_shape=ovo;, score=-0.480 total time=   0.0s
# [CV 3/5] END SVM__C=4.211105263157895, SVM__decision_function_shape=ovo;, score=-0.385 total time=   0.0s
# [CV 4/5] END SVM__C=4.211105263157895, SVM__decision_function_shape=ovo;, score=-0.448 total time=   0.0s
# [CV 5/5] END SVM__C=4.211105263157895, SVM__decision_function_shape=ovo;, score=-0.417 total time=   0.0s
# [CV 1/5] END SVM__C=4.211105263157895, SVM__decision_function_shape=ovr;, score=-0.408 total time=   0.0s
# [CV 2/5] END SVM__C=4.211105263157895, SVM__decision_function_shape=ovr;, score=-0.480 total time=   0.0s
# [CV 3/5] END SVM__C=4.211105263157895, SVM__decision_function_shape=ovr;, score=-0.385 total time=   0.0s
# [CV 4/5] END SVM__C=4.211105263157895, SVM__decision_function_shape=ovr;, score=-0.448 total time=   0.0s
# [CV 5/5] END SVM__C=4.211105263157895, SVM__decision_function_shape=ovr;, score=-0.417 total time=   0.0s
# [CV 1/5] END SVM__C=4.737368421052632, SVM__decision_function_shape=ovo;, score=-0.409 total time=   0.0s
# [CV 2/5] END SVM__C=4.737368421052632, SVM__decision_function_shape=ovo;, score=-0.484 total time=   0.0s
# [CV 3/5] END SVM__C=4.737368421052632, SVM__decision_function_shape=ovo;, score=-0.391 total time=   0.0s
# [CV 4/5] END SVM__C=4.737368421052632, SVM__decision_function_shape=ovo;, score=-0.451 total time=   0.0s
# [CV 5/5] END SVM__C=4.737368421052632, SVM__decision_function_shape=ovo;, score=-0.419 total time=   0.0s
# [CV 1/5] END SVM__C=4.737368421052632, SVM__decision_function_shape=ovr;, score=-0.409 total time=   0.0s
# [CV 2/5] END SVM__C=4.737368421052632, SVM__decision_function_shape=ovr;, score=-0.484 total time=   0.0s
# [CV 3/5] END SVM__C=4.737368421052632, SVM__decision_function_shape=ovr;, score=-0.391 total time=   0.0s
# [CV 4/5] END SVM__C=4.737368421052632, SVM__decision_function_shape=ovr;, score=-0.451 total time=   0.0s
# [CV 5/5] END SVM__C=4.737368421052632, SVM__decision_function_shape=ovr;, score=-0.419 total time=   0.0s
# [CV 1/5] END SVM__C=5.263631578947369, SVM__decision_function_shape=ovo;, score=-0.408 total time=   0.0s
# [CV 2/5] END SVM__C=5.263631578947369, SVM__decision_function_shape=ovo;, score=-0.488 total time=   0.0s
# [CV 3/5] END SVM__C=5.263631578947369, SVM__decision_function_shape=ovo;, score=-0.395 total time=   0.0s
# [CV 4/5] END SVM__C=5.263631578947369, SVM__decision_function_shape=ovo;, score=-0.457 total time=   0.0s
# [CV 5/5] END SVM__C=5.263631578947369, SVM__decision_function_shape=ovo;, score=-0.415 total time=   0.0s
# [CV 1/5] END SVM__C=5.263631578947369, SVM__decision_function_shape=ovr;, score=-0.408 total time=   0.0s
# [CV 2/5] END SVM__C=5.263631578947369, SVM__decision_function_shape=ovr;, score=-0.488 total time=   0.0s
# [CV 3/5] END SVM__C=5.263631578947369, SVM__decision_function_shape=ovr;, score=-0.395 total time=   0.0s
# [CV 4/5] END SVM__C=5.263631578947369, SVM__decision_function_shape=ovr;, score=-0.457 total time=   0.0s
# [CV 5/5] END SVM__C=5.263631578947369, SVM__decision_function_shape=ovr;, score=-0.415 total time=   0.0s
# [CV 1/5] END SVM__C=5.789894736842106, SVM__decision_function_shape=ovo;, score=-0.410 total time=   0.0s
# [CV 2/5] END SVM__C=5.789894736842106, SVM__decision_function_shape=ovo;, score=-0.492 total time=   0.0s
# [CV 3/5] END SVM__C=5.789894736842106, SVM__decision_function_shape=ovo;, score=-0.398 total time=   0.0s
# [CV 4/5] END SVM__C=5.789894736842106, SVM__decision_function_shape=ovo;, score=-0.464 total time=   0.0s
# [CV 5/5] END SVM__C=5.789894736842106, SVM__decision_function_shape=ovo;, score=-0.410 total time=   0.0s
# [CV 1/5] END SVM__C=5.789894736842106, SVM__decision_function_shape=ovr;, score=-0.410 total time=   0.0s
# [CV 2/5] END SVM__C=5.789894736842106, SVM__decision_function_shape=ovr;, score=-0.492 total time=   0.0s
# [CV 3/5] END SVM__C=5.789894736842106, SVM__decision_function_shape=ovr;, score=-0.398 total time=   0.0s
# [CV 4/5] END SVM__C=5.789894736842106, SVM__decision_function_shape=ovr;, score=-0.464 total time=   0.0s
# [CV 5/5] END SVM__C=5.789894736842106, SVM__decision_function_shape=ovr;, score=-0.410 total time=   0.0s
# [CV 1/5] END SVM__C=6.316157894736842, SVM__decision_function_shape=ovo;, score=-0.414 total time=   0.0s
# [CV 2/5] END SVM__C=6.316157894736842, SVM__decision_function_shape=ovo;, score=-0.497 total time=   0.0s
# [CV 3/5] END SVM__C=6.316157894736842, SVM__decision_function_shape=ovo;, score=-0.400 total time=   0.0s
# [CV 4/5] END SVM__C=6.316157894736842, SVM__decision_function_shape=ovo;, score=-0.468 total time=   0.0s
# [CV 5/5] END SVM__C=6.316157894736842, SVM__decision_function_shape=ovo;, score=-0.406 total time=   0.0s
# [CV 1/5] END SVM__C=6.316157894736842, SVM__decision_function_shape=ovr;, score=-0.414 total time=   0.0s
# [CV 2/5] END SVM__C=6.316157894736842, SVM__decision_function_shape=ovr;, score=-0.497 total time=   0.0s
# [CV 3/5] END SVM__C=6.316157894736842, SVM__decision_function_shape=ovr;, score=-0.400 total time=   0.0s
# [CV 4/5] END SVM__C=6.316157894736842, SVM__decision_function_shape=ovr;, score=-0.468 total time=   0.0s
# [CV 5/5] END SVM__C=6.316157894736842, SVM__decision_function_shape=ovr;, score=-0.406 total time=   0.0s
# [CV 1/5] END SVM__C=6.84242105263158, SVM__decision_function_shape=ovo;, score=-0.417 total time=   0.0s
# [CV 2/5] END SVM__C=6.84242105263158, SVM__decision_function_shape=ovo;, score=-0.502 total time=   0.0s
# [CV 3/5] END SVM__C=6.84242105263158, SVM__decision_function_shape=ovo;, score=-0.401 total time=   0.0s
# [CV 4/5] END SVM__C=6.84242105263158, SVM__decision_function_shape=ovo;, score=-0.468 total time=   0.0s
# [CV 5/5] END SVM__C=6.84242105263158, SVM__decision_function_shape=ovo;, score=-0.403 total time=   0.0s
# [CV 1/5] END SVM__C=6.84242105263158, SVM__decision_function_shape=ovr;, score=-0.417 total time=   0.0s
# [CV 2/5] END SVM__C=6.84242105263158, SVM__decision_function_shape=ovr;, score=-0.502 total time=   0.0s
# [CV 3/5] END SVM__C=6.84242105263158, SVM__decision_function_shape=ovr;, score=-0.401 total time=   0.0s
# [CV 4/5] END SVM__C=6.84242105263158, SVM__decision_function_shape=ovr;, score=-0.468 total time=   0.0s
# [CV 5/5] END SVM__C=6.84242105263158, SVM__decision_function_shape=ovr;, score=-0.403 total time=   0.0s
# [CV 1/5] END SVM__C=7.368684210526316, SVM__decision_function_shape=ovo;, score=-0.420 total time=   0.0s
# [CV 2/5] END SVM__C=7.368684210526316, SVM__decision_function_shape=ovo;, score=-0.508 total time=   0.0s
# [CV 3/5] END SVM__C=7.368684210526316, SVM__decision_function_shape=ovo;, score=-0.402 total time=   0.0s
# [CV 4/5] END SVM__C=7.368684210526316, SVM__decision_function_shape=ovo;, score=-0.469 total time=   0.0s
# [CV 5/5] END SVM__C=7.368684210526316, SVM__decision_function_shape=ovo;, score=-0.401 total time=   0.0s
# [CV 1/5] END SVM__C=7.368684210526316, SVM__decision_function_shape=ovr;, score=-0.420 total time=   0.0s
# [CV 2/5] END SVM__C=7.368684210526316, SVM__decision_function_shape=ovr;, score=-0.508 total time=   0.0s
# [CV 3/5] END SVM__C=7.368684210526316, SVM__decision_function_shape=ovr;, score=-0.402 total time=   0.0s
# [CV 4/5] END SVM__C=7.368684210526316, SVM__decision_function_shape=ovr;, score=-0.469 total time=   0.0s
# [CV 5/5] END SVM__C=7.368684210526316, SVM__decision_function_shape=ovr;, score=-0.401 total time=   0.0s
# [CV 1/5] END SVM__C=7.894947368421054, SVM__decision_function_shape=ovo;, score=-0.420 total time=   0.0s
# [CV 2/5] END SVM__C=7.894947368421054, SVM__decision_function_shape=ovo;, score=-0.511 total time=   0.0s
# [CV 3/5] END SVM__C=7.894947368421054, SVM__decision_function_shape=ovo;, score=-0.404 total time=   0.0s
# [CV 4/5] END SVM__C=7.894947368421054, SVM__decision_function_shape=ovo;, score=-0.468 total time=   0.0s
# [CV 5/5] END SVM__C=7.894947368421054, SVM__decision_function_shape=ovo;, score=-0.401 total time=   0.0s
# [CV 1/5] END SVM__C=7.894947368421054, SVM__decision_function_shape=ovr;, score=-0.420 total time=   0.0s
# [CV 2/5] END SVM__C=7.894947368421054, SVM__decision_function_shape=ovr;, score=-0.511 total time=   0.0s
# [CV 3/5] END SVM__C=7.894947368421054, SVM__decision_function_shape=ovr;, score=-0.404 total time=   0.0s
# [CV 4/5] END SVM__C=7.894947368421054, SVM__decision_function_shape=ovr;, score=-0.468 total time=   0.0s
# [CV 5/5] END SVM__C=7.894947368421054, SVM__decision_function_shape=ovr;, score=-0.401 total time=   0.0s
# [CV 1/5] END SVM__C=8.42121052631579, SVM__decision_function_shape=ovo;, score=-0.420 total time=   0.0s
# [CV 2/5] END SVM__C=8.42121052631579, SVM__decision_function_shape=ovo;, score=-0.515 total time=   0.0s
# [CV 3/5] END SVM__C=8.42121052631579, SVM__decision_function_shape=ovo;, score=-0.405 total time=   0.0s
# [CV 4/5] END SVM__C=8.42121052631579, SVM__decision_function_shape=ovo;, score=-0.467 total time=   0.0s
# [CV 5/5] END SVM__C=8.42121052631579, SVM__decision_function_shape=ovo;, score=-0.401 total time=   0.0s
# [CV 1/5] END SVM__C=8.42121052631579, SVM__decision_function_shape=ovr;, score=-0.420 total time=   0.0s
# [CV 2/5] END SVM__C=8.42121052631579, SVM__decision_function_shape=ovr;, score=-0.515 total time=   0.0s
# [CV 3/5] END SVM__C=8.42121052631579, SVM__decision_function_shape=ovr;, score=-0.405 total time=   0.0s
# [CV 4/5] END SVM__C=8.42121052631579, SVM__decision_function_shape=ovr;, score=-0.467 total time=   0.0s
# [CV 5/5] END SVM__C=8.42121052631579, SVM__decision_function_shape=ovr;, score=-0.401 total time=   0.0s
# [CV 1/5] END SVM__C=8.947473684210527, SVM__decision_function_shape=ovo;, score=-0.421 total time=   0.0s
# [CV 2/5] END SVM__C=8.947473684210527, SVM__decision_function_shape=ovo;, score=-0.520 total time=   0.0s
# [CV 3/5] END SVM__C=8.947473684210527, SVM__decision_function_shape=ovo;, score=-0.407 total time=   0.0s
# [CV 4/5] END SVM__C=8.947473684210527, SVM__decision_function_shape=ovo;, score=-0.467 total time=   0.0s
# [CV 5/5] END SVM__C=8.947473684210527, SVM__decision_function_shape=ovo;, score=-0.401 total time=   0.0s
# [CV 1/5] END SVM__C=8.947473684210527, SVM__decision_function_shape=ovr;, score=-0.421 total time=   0.0s
# [CV 2/5] END SVM__C=8.947473684210527, SVM__decision_function_shape=ovr;, score=-0.520 total time=   0.0s
# [CV 3/5] END SVM__C=8.947473684210527, SVM__decision_function_shape=ovr;, score=-0.407 total time=   0.0s
# [CV 4/5] END SVM__C=8.947473684210527, SVM__decision_function_shape=ovr;, score=-0.467 total time=   0.0s
# [CV 5/5] END SVM__C=8.947473684210527, SVM__decision_function_shape=ovr;, score=-0.401 total time=   0.0s
# [CV 1/5] END SVM__C=9.473736842105263, SVM__decision_function_shape=ovo;, score=-0.423 total time=   0.0s
# [CV 2/5] END SVM__C=9.473736842105263, SVM__decision_function_shape=ovo;, score=-0.525 total time=   0.0s
# [CV 3/5] END SVM__C=9.473736842105263, SVM__decision_function_shape=ovo;, score=-0.409 total time=   0.0s
# [CV 4/5] END SVM__C=9.473736842105263, SVM__decision_function_shape=ovo;, score=-0.467 total time=   0.0s
# [CV 5/5] END SVM__C=9.473736842105263, SVM__decision_function_shape=ovo;, score=-0.404 total time=   0.0s
# [CV 1/5] END SVM__C=9.473736842105263, SVM__decision_function_shape=ovr;, score=-0.423 total time=   0.0s
# [CV 2/5] END SVM__C=9.473736842105263, SVM__decision_function_shape=ovr;, score=-0.525 total time=   0.0s
# [CV 3/5] END SVM__C=9.473736842105263, SVM__decision_function_shape=ovr;, score=-0.409 total time=   0.0s
# [CV 4/5] END SVM__C=9.473736842105263, SVM__decision_function_shape=ovr;, score=-0.467 total time=   0.0s
# [CV 5/5] END SVM__C=9.473736842105263, SVM__decision_function_shape=ovr;, score=-0.404 total time=   0.0s
# [CV 1/5] END SVM__C=10.0, SVM__decision_function_shape=ovo;, score=-0.425 total time=   0.0s
# [CV 2/5] END SVM__C=10.0, SVM__decision_function_shape=ovo;, score=-0.530 total time=   0.0s
# [CV 3/5] END SVM__C=10.0, SVM__decision_function_shape=ovo;, score=-0.410 total time=   0.0s
# [CV 4/5] END SVM__C=10.0, SVM__decision_function_shape=ovo;, score=-0.467 total time=   0.0s
# [CV 5/5] END SVM__C=10.0, SVM__decision_function_shape=ovo;, score=-0.407 total time=   0.0s
# [CV 1/5] END SVM__C=10.0, SVM__decision_function_shape=ovr;, score=-0.425 total time=   0.0s
# [CV 2/5] END SVM__C=10.0, SVM__decision_function_shape=ovr;, score=-0.530 total time=   0.0s
# [CV 3/5] END SVM__C=10.0, SVM__decision_function_shape=ovr;, score=-0.410 total time=   0.0s
# [CV 4/5] END SVM__C=10.0, SVM__decision_function_shape=ovr;, score=-0.467 total time=   0.0s
# [CV 5/5] END SVM__C=10.0, SVM__decision_function_shape=ovr;, score=-0.407 total time=   0.0s
# GridSearchCV(cv=StratifiedKFold(n_splits=5, random_state=2022, shuffle=True),
#              estimator=Pipeline(steps=[('STD', StandardScaler()),
#                                        ('SVM',
#                                         SVC(kernel='linear', probability=True,
#                                             random_state=2022))]),
#              param_grid={'SVM__C': array([1.00000000e-03, 5.27263158e-01, 1.05352632e+00, 1.57978947e+00,
#        2.10605263e+00, 2.63231579e+00, 3.15857895e+00, 3.68484211e+00,
#        4.21110526e+00, 4.73736842e+00, 5.26363158e+00, 5.78989474e+00,
#        6.31615789e+00, 6.84242105e+00, 7.36868421e+00, 7.89494737e+00,
#        8.42121053e+00, 8.94747368e+00, 9.47373684e+00, 1.00000000e+01]),
#                          'SVM__decision_function_shape': ['ovo', 'ovr']},
#              scoring='neg_log_loss', verbose=3)

# %%
print(gcv.best_params_)
# Out:
# {'SVM__C': 1.0535263157894736, 'SVM__decision_function_shape': 'ovo'}

# %%
print(gcv.best_score_)
# Out:
# -0.40457971833739437
