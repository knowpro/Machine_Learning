# %%
import pandas as pd
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
fp_df = pd.read_csv(r"C:\Hogwarts\machine_learning\11. Association Rules\Association Datasets\Cosmetics.csv",
           index_col = 0)

# %%
fp_df.head()
# Out:
#          Bag  Blush  Nail Polish  Brushes  Concealer  Eyebrow Pencils  \
# Trans.
# 1          0      1            1        1          1                0
# 2          0      0            1        0          1                0
# 3          0      1            0        0          1                1
# 4          0      0            1        1          1                0
# 5          0      1            0        0          1                0
#
#          Bronzer  Lip liner  Mascara  Eye shadow  Foundation  Lip Gloss  \
# Trans.
# 1              1          1        1           0           0          0
# 2              1          1        0           0           1          1
# 3              1          1        1           1           1          1
# 4              1          0        0           0           1          0
# 5              1          1        1           1           0          1
#
#          Lipstick  Eyeliner
# Trans.
# 1               0         1
# ...

# %% [markdown]
# ## Create Frequent ItemSet

# %%
itemset = apriori(fp_df,
                min_support = 0.1,
                use_colnames = True)
itemset#.head()
# Out:
# C:\Users\admin\anaconda3\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:111: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
#      support                                      itemsets
# 0      0.363                                       (Blush)
# 1      0.280                                 (Nail Polish)
# 2      0.149                                     (Brushes)
# 3      0.442                                   (Concealer)
# 4      0.279                                     (Bronzer)
# ..       ...                                           ...
# 97     0.116             (Lipstick, Lip Gloss, Foundation)
# 98     0.156             (Eyeliner, Lip Gloss, Foundation)
# 99     0.119       (Eye shadow, Concealer, Blush, Mascara)
# 100    0.114    (Eye shadow, Eyeliner, Concealer, Mascara)
# ...

# %% [markdown]
# # Convert into rules

# %%
rules = association_rules(itemset)
rules.head()
# Out:
#            antecedents    consequents  antecedent support  consequent support  \
# 0            (Brushes)  (Nail Polish)               0.149               0.280
# 1         (Eye shadow)      (Mascara)               0.381               0.357
# 2            (Mascara)   (Eye shadow)               0.357               0.381
# 3   (Blush, Lip liner)    (Concealer)               0.124               0.442
# 4  (Eye shadow, Blush)      (Mascara)               0.182               0.357
#
#    support  confidence      lift  leverage  conviction
# 0    0.149    1.000000  3.571429  0.107280         inf
# 1    0.321    0.842520  2.359999  0.184983    4.083050
# 2    0.321    0.899160  2.359999  0.184983    6.138417
# 3    0.108    0.870968  1.970515  0.053192    4.324500
# 4    0.169    0.928571  2.601040  0.104026    9.002000

# %%
rules.sort_values( by = ["lift", "confidence"],
                 ascending = False)
# Out:
#                           antecedents    consequents  antecedent support  \
# 0                           (Brushes)  (Nail Polish)               0.149
# 21     (Eye shadow, Blush, Concealer)      (Mascara)               0.124
# 4                 (Eye shadow, Blush)      (Mascara)               0.182
# 6           (Eye shadow, Nail Polish)      (Mascara)               0.131
# 11            (Eye shadow, Concealer)      (Mascara)               0.201
# 13              (Eye shadow, Bronzer)      (Mascara)               0.141
# 23  (Eye shadow, Eyeliner, Concealer)      (Mascara)               0.130
# 5                    (Blush, Mascara)   (Eye shadow)               0.184
# 17             (Eye shadow, Lipstick)      (Mascara)               0.129
# 18                (Lipstick, Mascara)   (Eye shadow)               0.121
# 22        (Mascara, Blush, Concealer)   (Eye shadow)               0.131
# 14                 (Mascara, Bronzer)   (Eye shadow)               0.137
# ...
