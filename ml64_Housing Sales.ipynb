# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"Cases\House Property Sales Time Series\raw_sales.csv",
                 parse_dates = ["datesold"])

# %%
df
# Out:
#         datesold  postcode   price propertyType  bedrooms
# 0     2007-02-07      2607  525000        house         4
# 1     2007-02-27      2906  290000        house         3
# 2     2007-03-07      2905  328000        house         3
# 3     2007-03-09      2905  380000        house         4
# 4     2007-03-21      2906  310000        house         3
# ...          ...       ...     ...          ...       ...
# 29575 2019-07-25      2900  500000         unit         3
# 29576 2019-07-25      2612  560000         unit         2
# 29577 2019-07-26      2912  464950         unit         2
# 29578 2019-07-26      2601  589000         unit         2
# 29579 2019-07-26      2612  775000         unit         2
#
# [29580 rows x 5 columns]

# %%
df["year"] = df["datesold"].dt.year
df["month"] = df["datesold"].dt.month
df.head()
# Out:
#     datesold  postcode   price propertyType  bedrooms  year  month
# 0 2007-02-07      2607  525000        house         4  2007      2
# 1 2007-02-27      2906  290000        house         3  2007      2
# 2 2007-03-07      2905  328000        house         3  2007      3
# 3 2007-03-09      2905  380000        house         4  2007      3
# 4 2007-03-21      2906  310000        house         3  2007      3

# %%
total_sales = df.groupby(["year", "month"])["price"].sum()
total_sales = total_sales.reset_index()
total_sales.tail()
# Out:
#      year  month      price
# 145  2019      3  153793350
# 146  2019      4  138929019
# 147  2019      5  141128050
# 148  2019      6   88612700
# 149  2019      7  145798014

# %%
#

# %%
y = total_sales["price"]
y_train = y[:-6]
y_test = y[-6:]

# %%
plt.plot(y_train,
        color = "blue",
        label = "Train")

plt.plot(y_test,
        color = "orange",
        label = "Test")

plt.legend(loc = "best")
plt.show()
